# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Mon Aug 31 12:44:14 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Mounting Google Drive and listing the contents.  
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %% [markdown]
# **1) Clone the Darknet**

# %%
#Cloning the github of darknet directory. 
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14285, done.
# remote: Total 14285 (delta 0), reused 0 (delta 0), pack-reused 14285
# Receiving objects: 100% (14285/14285), 12.84 MiB | 16.29 MiB/s, done.
# Resolving deltas: 100% (9750/9750), done.

# %% [markdown]
# **2) Compile Darknet using Nvidia GPU**

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %%
# Create folder on google drive so that we can save there the weights
# !mkdir "/mydrive/yolov3"

# %%
#Giving the label of images 
# !echo "plate" > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-08-31 12:47:45--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   225KB/s    in 15m 10s
#
# 2020-08-31 13:02:56 (174 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
# !unzip /content/sample_data/images.zip -d data/obj

# %%
# We're going to convert the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
import glob
import os
import re

txt_file_paths = glob.glob(r"data/obj/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)

# %%
import glob
images_list = glob.glob("data/obj/images/*.jpeg")
print(images_list)
# Out:
# ['data/obj/images/im177.jpeg', 'data/obj/images/im207.jpeg', 'data/obj/images/im144.jpeg', 'data/obj/images/im133.jpeg', 'data/obj/images/im213.jpeg', 'data/obj/images/im200.jpeg', 'data/obj/images/im90.jpeg', 'data/obj/images/im125.jpeg', 'data/obj/images/im94.jpeg', 'data/obj/images/im78.jpeg', 'data/obj/images/im124.jpeg', 'data/obj/images/im3.jpeg', 'data/obj/images/im134.jpeg', 'data/obj/images/im12.jpeg', 'data/obj/images/im19.jpeg', 'data/obj/images/im231.jpeg', 'data/obj/images/im17.jpeg', 'data/obj/images/im217.jpeg', 'data/obj/images/im204.jpeg', 'data/obj/images/im199.jpeg', 'data/obj/images/im53.jpeg', 'data/obj/images/im159.jpeg', 'data/obj/images/im30.jpeg', 'data/obj/images/im111.jpeg', 'data/obj/images/im52.jpeg', 'data/obj/images/im195.jpeg', 'data/obj/images/im164.jpeg', 'data/obj/images/im73.jpeg', 'data/obj/images/im47.jpeg', 'data/obj/images/im182.jpeg', 'data/obj/images/im75.jpeg', 'data/obj/images/im97.jpeg', 'data/obj/images/im91.jpeg', 'data/obj/images/im141.jpeg', 'data/obj/images/im135.jpeg', 'data/obj/images/im129.jpeg', 'data/obj/images/im98.jpeg', 'data/obj/images/im68.jpeg', 'data/obj/images/im197.jpeg', 'data/obj/images/im219.jpeg', 'data/obj/images/im117.jpeg', 'data/obj/images/im190.jpeg', 'data/obj/images/im46.jpeg', 'data/obj/images/im6.jpeg', 'data/obj/images/im34.jpeg', 'data/obj/images/im27.jpeg', 'data/obj/images/im22.jpeg', 'data/obj/images/im101.jpeg', 'data/obj/images/im150.jpeg', 'data/obj/images/im18.jpeg', 'data/obj/images/im229.jpeg', 'data/obj/images/im210.jpeg', 'data/obj/images/im10.jpeg', 'data/obj/images/im183.jpeg', 'data/obj/images/im65.jpeg', 'data/obj/images/im74.jpeg', 'data/obj/images/im151.jpeg', 'data/obj/images/im86.jpeg', 'data/obj/images/im87.jpeg', 'data/obj/images/im208.jpeg', 'data/obj/images/im224.jpeg', 'data/obj/images/im82.jpeg', 'data/obj/images/im131.jpeg', 'data/obj/images/im172.jpeg', 'data/obj/images/im192.jpeg', 'data/obj/images/im35.jpeg', 'data/obj/images/im11.jpeg', 'data/obj/images/im49.jpeg', 'data/obj/images/im95.jpeg', 'data/obj/images/im201.jpeg', 'data/obj/images/im100.jpeg', 'data/obj/images/im32.jpeg', 'data/obj/images/im14.jpeg', 'data/obj/images/im234.jpeg', 'data/obj/images/im191.jpeg', 'data/obj/images/im138.jpeg', 'data/obj/images/im214.jpeg', 'data/obj/images/im119.jpeg', 'data/obj/images/im55.jpeg', 'data/obj/images/im198.jpeg', 'data/obj/images/im79.jpeg', 'data/obj/images/im193.jpeg', 'data/obj/images/im154.jpeg', 'data/obj/images/im64.jpeg', 'data/obj/images/im25.jpeg', 'data/obj/images/im148.jpeg', 'data/obj/images/im120.jpeg', 'data/obj/images/im69.jpeg', 'data/obj/images/im23.jpeg', 'data/obj/images/im83.jpeg', 'data/obj/images/im136.jpeg', 'data/obj/images/im205.jpeg', 'data/obj/images/im128.jpeg', 'data/obj/images/im26.jpeg', 'data/obj/images/im132.jpeg', 'data/obj/images/im89.jpeg', 'data/obj/images/im202.jpeg', 'data/obj/images/im109.jpeg', 'data/obj/images/im216.jpeg', 'data/obj/images/im62.jpeg', 'data/obj/images/im81.jpeg', 'data/obj/images/im9.jpeg', 'data/obj/images/im4.jpeg', 'data/obj/images/im103.jpeg', 'data/obj/images/im93.jpeg', 'data/obj/images/im232.jpeg', 'data/obj/images/im223.jpeg', 'data/obj/images/im36.jpeg', 'data/obj/images/im226.jpeg', 'data/obj/images/im43.jpeg', 'data/obj/images/im40.jpeg', 'data/obj/images/im116.jpeg', 'data/obj/images/im155.jpeg', 'data/obj/images/im20.jpeg', 'data/obj/images/im143.jpeg', 'data/obj/images/im102.jpeg', 'data/obj/images/im76.jpeg', 'data/obj/images/im126.jpeg', 'data/obj/images/im16.jpeg', 'data/obj/images/im152.jpeg', 'data/obj/images/im60.jpeg', 'data/obj/images/im235.jpeg', 'data/obj/images/im99.jpeg', 'data/obj/images/im122.jpeg', 'data/obj/images/im171.jpeg', 'data/obj/images/im160.jpeg', 'data/obj/images/im166.jpeg', 'data/obj/images/im142.jpeg', 'data/obj/images/im161.jpeg', 'data/obj/images/im206.jpeg', 'data/obj/images/im163.jpeg', 'data/obj/images/im180.jpeg', 'data/obj/images/im157.jpeg', 'data/obj/images/im146.jpeg', 'data/obj/images/im92.jpeg', 'data/obj/i ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %% [markdown]
# **6) Start the training**

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
